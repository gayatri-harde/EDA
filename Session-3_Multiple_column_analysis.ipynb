# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path1= r'Visadataset.csv'
visa_df = pd.read_csv(path1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat = visa_df.select_dtypes(include = 'object').columns
num = visa_df.select_dtypes(exclude = 'object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
continent_keys = visa_df['continent'].value_counts().keys()
continent_values = visa_df['continent'].value_counts().values

df = pd.DataFrame(zip(continent_keys,continent_values),columns = ['Labels','No of Applicants'])
df.to_csv('continent_data.csv')

# %% [markdown]
# - I want to create all frequency table
#
# - and save in a new folder
#
# - The folder is available in python current file location
#
# - All step Automate

# %% [markdown]
# **step-1: create a folder using python code**

# %%
import os
try:
    os.makedirs('frequency_table')
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'frequency_table'

# %%
os.makedirs('frequency_table1',exist_ok=True)

# %%
continent_keys = visa_df['continent'].value_counts().keys()
continent_values = visa_df['continent'].value_counts().values

df = pd.DataFrame(zip(continent_keys,continent_values),columns = ['Labels','No of Applicants'])

#absolute path
path = r"C:\Users\HP\OneDrive\Documents\FSDS GenAI & Agentic AI\Naresh IT\EDA\frequency_table/continent_data.csv"
df.to_csv(path,index=False)

# %% [markdown]
# **Method-1**

# %%
#absolute path
path = r"C:\Users\HP\OneDrive\Documents\FSDS GenAI & Agentic AI\Naresh IT\EDA\frequency_tablecontinent_data.csv"
df.to_csv(path,index=False)

# %% [markdown]
# **Method-2**

# %%
# relative path
path = r".\frequency_table/continent_data1.csv"
df.to_csv(path,index=False)

# %% [markdown]
# **Method-3**

# %%
cwd = os.getcwd()
folder_name = 'frequency_table'
new_dir = os.path.join(cwd,folder_name)
file_name = 'continent_data2.csv'
path = os.path.join(new_dir,file_name)
df.to_csv(path,index=False)

# %%
#step-1 :created table
continent_keys = visa_df['continent'].value_counts().keys()
continent_values = visa_df['continent'].value_counts().values

df = pd.DataFrame(zip(continent_keys,continent_values),columns = ['Labels','No of Applicants'])

#step-2: 
folder_name = 'frequency_table'
os.makedirs(folder_name,exist_ok= True)

#step-3: Create folder
cwd = os.getcwd()
new_dir = os.path.join(cwd,folder_name)
file_name = 'continent.csv'
path = os.path.join(new_dir,file_name)

#step-4: save
df.to_csv(path,index=False)

# %% [markdown]
# **Multiple Column Analysis**

# %%
for i in cat[1:]:
    continent_keys = visa_df[i].value_counts().keys()
    continent_values = visa_df[i].value_counts().values
    
    df = pd.DataFrame(zip(continent_keys,continent_values),columns = ['Labels','No of Applicants'])
    
    folder_name = 'frequency_table'
    os.makedirs(folder_name,exist_ok= True)
    
    cwd = os.getcwd()
    new_dir = os.path.join(cwd,folder_name)
    file_name = f'{i}.csv'
    path = os.path.join(new_dir,file_name)
    
    df.to_csv(path,index=False)

# %% [markdown]
# **Bar Chart Automation**

# %%
# step-1:
for i in cat[1:]:  # misrake cat:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.figure(figsize=(10,4))
    plt.bar(keys,values)
    # step-2
    folder_name='Bar_charts'
    os.makedirs(folder_name,exist_ok=True)
    
    # step-3: 
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.jpg'
    path=os.path.join(new_dir,file_name)
    
    # step-4:
    plt.savefig(path)

# %% [markdown]
# **Pie_Chart Automation**

# %%
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    plt.figure(figsize = (10,4))
    plt.pie(values,
            labels = keys,explode = [0.1*i for i in range(len(keys))])
    plt.savefig(f'{i}_pie_chart.jpg')
    folder_name = 'pie_charts'
    os.makedirs(folder_name,exist_ok= True)
    cwd = os.getcwd()
    new_dir = os.path.join(cwd,folder_name)
    file_name = f'{i}.jpg'
    path = os.path.join(new_dir,file_name)
    plt.savefig(path)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

path1= r'Visadataset.csv'
visa_df = pd.read_csv(path1)
cat = visa_df.select_dtypes(include = 'object').columns
num = visa_df.select_dtypes(exclude = 'object').columns

# %%
#bar cahrt for continent
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values
plt.figure(figsize = (10,4))
plt.bar(keys,values)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# **subplots**
#
# - multiplots we can plot in a single area

# %%
plt.subplot(2,2,1)
plt.title('2-2-1')
plt.subplot(2,2,2)
plt.title('2-2-2')
plt.subplot(2,2,3)
plt.title('2-2-3')
plt.subplot(2,2,4)
plt.title('2-2-4')
# Out:
# Text(0.5, 1.0, '2-2-4')

# %%
plt.subplot(1,3,1)
plt.subplot(1,3,2)
plt.subplot(1,3,3)
# Out:
# <Axes: >

# %%
plt.subplot(3,1,1)
plt.subplot(3,1,2)
plt.subplot(3,1,3)
# Out:
# <Axes: >

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
#plt.subplot(2,2,1)
#plt.subplot(2,2,2)
#plt.subplot(2,2,3)
#plt.subplot(2,2,4)
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
for i in range(1,10):
    plt.subplot(3,3,i)

# %% [raw]
# for i in range(1,10):
#     plt.subplot(3,3,i)

# %%
plt.figure(figsize = (16,8))
for i in range(1,len(cat)):     # cat[0] case id we are not using cat[1]
    #print(i,cat[i])
    keys = visa_df[cat[i]].value_counts().keys() #i : num cat[i] columns
    values = visa_df[cat[i]].value_counts().values  #i : columns name
    plt.subplot(3,3,i)                                   #i: number
    plt.bar(keys,values)

# %%
plt.figure(figsize = (28,10))
for i in range(1,len(cat)):     # cat[0] case id we are not using cat[1]
    #print(i,cat[i])
    keys = visa_df[cat[i]].value_counts().keys() #i : num cat[i] columns
    values = visa_df[cat[i]].value_counts().values  #i : columns name
    plt.subplot(3,3,i).bar(keys,values)                                  #i: number
    plt.title(f'{cat[i]}_bar_chart')
    plt.suptitle('Barcharts')
