# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

path1= r'Visadataset.csv'
visa_df = pd.read_csv(path1)
visa_df
cat = visa_df.select_dtypes(include = 'object').columns
num = visa_df.select_dtypes(exclude = 'object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **Prevailing_wage**

# %% [markdown]
# - len
# - max
# - min
# - mean
# - median
# - 25 percentile
# - 50 percentile
# - 75 percentile

# %%
wage_data = visa_df['prevailing_wage']
len(wage_data)
# Out:
# 25480

# %%
min(wage_data)
# Out:
# 2.1367

# %%
wage_data.min()
# Out:
# 2.1367

# %%
np.min(wage_data)
# Out:
# 2.1367

# %%
wage_data = visa_df['prevailing_wage']
min(wage_data),wage_data.min(),np.min(wage_data)
# Out:
# (2.1367, 2.1367, 2.1367)

# %%
wage_data = visa_df['prevailing_wage']
max(wage_data),wage_data.max(),np.max(wage_data)
# Out:
# (319210.27, 319210.27, 319210.27)

# %%
wage_data.mean(),np.mean(wage_data)
# Out:
# (74455.81459209183, 74455.81459209183)

# %%
wage_data.median(),np.median(wage_data)
# Out:
# (70308.20999999999, 70308.20999999999)

# %% [markdown]
# **quntile-percentile**

# %%
p_25 = np.percentile(wage_data,25)
p_25
# Out:
# 34015.479999999996

# %%
p_50 = np.percentile(wage_data,50)
p_50
# Out:
# 70308.20999999999

# %%
p_75 = np.percentile(wage_data,75)
p_75
# Out:
# 107735.51250000001

# %%
q_25 = np.quantile(wage_data,0.25)
q_25
# Out:
# 34015.479999999996

# %%
q_50 = np.quantile(wage_data,0.50)
q_50
# Out:
# 70308.20999999999

# %%
q_75 = np.quantile(wage_data,0.75)
q_75
# Out:
# 107735.51250000001

# %%
wage_count = len(wage_data)
wage_min = round(wage_data.min(),2)
wage_max = round(wage_data.max(),2)
wage_mean = round(wage_data.mean(),2)
wage_median = round(wage_data.median(),2)
wage_25 = round(np.percentile(wage_data,25),2)
wage_50 = round(np.percentile(wage_data,50),2)
wage_75 = round(np.percentile(wage_data,75),2)
l = [wage_count,wage_min,wage_max,wage_mean,wage_median,wage_25,wage_50,wage_75]
idx = ['Count','Min','Max','Mean','Median','25','50','75']
pd.DataFrame(l,index = idx,columns = ['Previling Wage'])
# Out:
#         Previling Wage
# Count         25480.00
# Min               2.14
# Max          319210.27
# Mean          74455.81
# Median        70308.21
# 25            34015.48
# 50            70308.21
# 75           107735.51

# %%
wage_count = len(wage_data)
wage_min = round(wage_data.min(),2)
wage_mean = round(wage_data.mean(),2)
wage_median = round(wage_data.median(),2)
wage_25 = round(np.percentile(wage_data,25))
wage_50 = round(np.percentile(wage_data,50))
wage_75 = round(np.percentile(wage_data,75))
wage_max = round(wage_data.max(),2)
l = [wage_count,wage_min,wage_mean,wage_median,wage_25,wage_50,wage_75,wage_max]
Id = ['Count','Min','Mean','Median','25P','50P','75P','MAX']
pd.DataFrame(l,columns=['previling_wage'],index = Id)
# Out:
#         previling_wage
# Count         25480.00
# Min               2.14
# Mean          74455.81
# Median        70308.21
# 25P           34015.00
# 50P           70308.00
# 75P          107736.00
# MAX          319210.27

# %%
L = []
for i in num:
    data = visa_df[i]
    count = len(data)
    Min = round(data.min(),2)
    Mean = round(data.mean(),2)
    Median = round(data.median(),2)
    p_25 = round(np.percentile(data,25))
    p_50 = round(np.percentile(data,50))
    p_75 = round(np.percentile(data,75))
    Max = round(wage_data.max(),2)
    l = [count,Min,Mean,Median,p_25,p_50,p_75,Max]
    L.append(l)
    Id = ['Count','Min','Mean','Median','25P','50P','75P','MAX']
pd.DataFrame(L,columns=Id,
                 index = num).T
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# Count          25480.00     25480.00         25480.00
# Min              -26.00      1800.00             2.14
# Mean            5667.04      1979.41         74455.81
# Median          2109.00      1997.00         70308.21
# 25P             1022.00      1976.00         34015.00
# 50P             2109.00      1997.00         70308.00
# 75P             3504.00      2005.00        107736.00
# MAX           319210.27    319210.27        319210.27

# %%
L = []
for i in num:
    data = visa_df[i]
    Count = len(data)
    Min = round(data.min(),2)
    Mean = round(data.mean(),2)
    Median = round(data.median(),2)
    p_25 = round(np.percentile(data,25))
    p_50 = round(np.percentile(data,50))
    p_75 = round(np.percentile(data,75))
    Max = round(data.max(),2)
    l = [Count,Min,Mean,Median,p_25,p_50,p_75,Max]
    L.append(l)
    Id = ['Count','Min','Mean','Median','25P','50P','75P','MAX']

# %%
pd.DataFrame(L,columns = Id,index = num).T
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# Count          25480.00     25480.00         25480.00
# Min              -26.00      1800.00             2.14
# Mean            5667.04      1979.41         74455.81
# Median          2109.00      1997.00         70308.21
# 25P             1022.00      1976.00         34015.00
# 50P             2109.00      1997.00         70308.00
# 75P             3504.00      2005.00        107736.00
# MAX           602069.00      2016.00        319210.27

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **percentile**

# %% [markdown]
# - 25p: 25 percent of data below 25p value
#
# - wage_data25p: 34015.480000
#     - there are 25*(25480)/100 = 6370 applicants have salary less than 34015 dollor
#
# - wage_data50p: 70308.210000
#     - there are 50*(25480)/100 = 12740.0 applicants have salary less than 70308 dollor
#
# - wage_data75p: 107735.512500
#     - there are 75*(25480)/100 = 19110.0 applicants have salary less than 107735 dollor

# %%
con = visa_df['prevailing_wage'] < wage_25
len(visa_df[con]),len(visa_df)*25/100
len(visa_df[con]) == len(visa_df)*25/100
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
con = visa_df['prevailing_wage'] < wage_25
len(visa_df[con]) == 25*(25480)/100
# Out:
# True

# %%
con = visa_df['prevailing_wage'] < wage_50
len(visa_df[con]),len(visa_df)*50/100
len(visa_df[con]) == len(visa_df)*50/100
len(visa_df[con]) == 50*(25480)/100
# Out:
# True

# %%
con = visa_df['prevailing_wage'] < wage_75
len(visa_df[con]),len(visa_df)*75/100
len(visa_df[con]) == len(visa_df)*75/100
len(visa_df[con]) == 75*(25480)/100
# Out:
# True

# %% [markdown]
# **Emperical Rule**
#
# - u-1*sigma
# - to u+1*sigma 68%
#
# step-1 : wage data mean (u)
#
# step-2 : wage data std (sigma)
#
# step-3 : LB = u-1*sigma
#
# step-4 : UB = u+1*sigma
#
# step-5 : con1 = visa_df['prevailing_wage'] > LB
#
# step-6 : con2 = visa_df['prevailing_wage'] < UB
#
# step-7 : con = con1 & con2
#
# step-8 : len(visa_df[con])

# %%
u = wage_data.mean()
sigma = wage_data.std()
LB = u-1*sigma
UB = u+1*sigma
con1 = visa_df['prevailing_wage']>LB
con2 = visa_df['prevailing_wage']<UB
con = con1 & con2
visa_df[con1]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
len(visa_df[con])
# Out:
# 17171

# %%
visa_df['prevailing_wage'] == 68*(25480)/100 # Not  follow normal distribution
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476    False
# 25477    False
# 25478    False
# 25479    False
# Name: prevailing_wage, Length: 25480, dtype: bool

# %% [markdown]
# **Conculsion**: Emperical Rule fail wage data does not following Normal Distribution

# %% [markdown]
# **Histogram**

# %%
plt.hist(wage_data)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(wage_data,bins = 10)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(wage_data,bins = 40)
# Out:
# (array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#         1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#          509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#           79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#            7.,    3.,    6.,    5.]),
#  array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#         3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#         6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#         9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#         1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#         1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#         1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#         2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#         2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
# ...

# %%
inter_count, inter_vals,n = plt.hist(wage_data,bins = 10)

# %%
inter_count
# Out:
# array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#          21.])

# %%
inter_vals
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %%
n
# Out:
# <BarContainer object of 10 artists>

# %%
lb = 2.13670000e+00
ub = 3.19229500e+04
con1 = visa_df['prevailing_wage'] >= lb
con2 = visa_df['prevailing_wage'] < ub
con = con1 & con2
len(visa_df[con])
# Out:
# 5504

# %%
lb = 2.13670000e+00
ub = 3.19229500e+04
con1 = visa_df['prevailing_wage']>=lb
con2 = visa_df['prevailing_wage']<ub
con = con1 & con2

# %%
len(visa_df[con])
# Out:
# 6038

# %%
inter_vals
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %% [markdown]
# **Outlier Analysis**

# %% [markdown]
# - we understood emperical rule FAILED
# - Then we plotted histogram its slightly deviated
# - So it indicates the data has outlier
# - Outlier can be show by **box plot**
#
#       Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                        |-----:-----|
#        o      |--------|     :     |--------|    o  o
#                        |-----:----
#          flier                        fliers
#                             IQR
#  IQR
# IQR

# %% [markdown]
# $box plot$

# %%
wage_data = visa_df['prevailing_wage']
plt.boxplot(wage_data,vert = False)
plt.show()

# %%
plt.figure(figsize = (8,4))
plt.subplot(1,2,1).hist(wage_data)
plt.subplot(1,2,2).boxplot(wage_data,vert = False)
plt.show()

# %% [markdown]
# **how many outliers are there**

# %% [markdown]
# **Outlier Data**

# %%
# q1
# q2
# q3
# IQR = q3-q1
# UB = q3+1.5*IQR
# LB = q1-1.5*IQR
# con1 = wage > UB
#con2 = Wage < LB
# con = con1 | con2 Outlier

# %%
len(visa_df)
# Out:
# 25480

# %%
q1 = round(np.percentile(wage_data,25),2)
q2 = round(np.percentile(wage_data,50),2)
q3 = round(np.percentile(wage_data,75),2)
IQR = q3-q1
UB = q3+1.5*IQR
LB = q1-1.5*IQR
con1 = wage_data > UB
con2 = wage_data < LB
con = con1 | con2
outlier_data = visa_df[con]
len(outlier_data)
# Out:
# 427

# %%
# Outlier data
q1 = round(np.percentile(data,25))
q2 =  round(np.percentile(data,50))
q3 = round(np.percentile(data,75))
IQR = q3-q1
UB = q3+1.5*IQR
LB = q1-1.5*IQR
con1 = wage_data > UB
con2 = wage_data < LB
con = con1 | con2
outlier_df = visa_df[con]

# %%
len(outlier_df)
# Out:
# 427

# %%
outlier_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
q1 = round(np.percentile(data,25))
q2 =  round(np.percentile(data,50))
q3 = round(np.percentile(data,75))
IQR = q3-q1
UB = q3+1.5*IQR
LB = q1-1.5*IQR
con1 = wage_data < UB
con2 = wage_data > LB
con = con1 & con2
non_outlier_df = visa_df[con]
len(non_outlier_df)
# Out:
# 25053

# %%
non_outlier_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
q1 = round(np.percentile(wage_data,25),2)
q2 = round(np.percentile(wage_data,50),2)
q3 = round(np.percentile(wage_data,75),2)
IQR = q3-q1
UB = q3+1.5*IQR
LB = q1-1.5*IQR
con1 = wage_data < UB
con2 = wage_data > LB
con = con1 & con2
non_outlier_df = visa_df[con]
len(non_outlier_df)
# Out:
# 25053

# %%
25053+427 == 25480
# Out:
# True

# %% [markdown]
# **Fill the outliers**
#
# - drop the outlier
#
# - fill with median
#
# - winsorization : fill with LB and UB

# %%
#we will iterate each value from wage_Data
# if the value matches

# %%
#con1 = wage_data > UB
#con2 = wage_data < LB
#con = con1 | con2
#outlier_df = visa_df[con]
# we will iterate each value from wage data
# if the value matches:

# %%
outlier_df
outlier_df['prevailing_wage']
outlier_df['prevailing_wage'].values
outlier = outlier_df['prevailing_wage'].values.tolist()
wage_data = visa_df['prevailing_wage']
l = []
wage_median = round(wage_data.median(),2)
for value in wage_data:
    if value in outlier:
        l.append(wage_median)
    else:
        l.append(value)

visa_df['prevailing_wage1'] = l
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# fill the outlier using median
outlier_df
outlier_df['prevailing_wage']
outlier_df['prevailing_wage'].values

# fill the outlier using median
outliers = outlier_df['prevailing_wage'].values.tolist()
wage_data = visa_df['prevailing_wage']
wage_med = wage_data.median()
l = []
for value in visa_df['prevailing_wage']:
    if value in outliers:
        l.append(wage_med)
    else:
        l.append(value)
visa_df['prevailing_wage1'] = l
visa_df['prevailing_wage1']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476     70308.2100
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage1, Length: 25480, dtype: float64

# %%
outlier_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
plt.boxplot(visa_df['prevailing_wage1'],vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c3681cff80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c3681fc4d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c3681bfe60>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c3681fca40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c3681fcd10>],
#  'means': []}

# %%
plt.figure(figsize = (8,4))
plt.subplot(1,2,1).hist(visa_df['prevailing_wage1'])
plt.subplot(1,2,2).boxplot(visa_df['prevailing_wage1'],vert = False)
plt.show()

# %%
plt.figure(figsize = (8,4))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage1'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage1'],vert = False)
plt.subplot(2,2,3).hist(wage_data)
plt.subplot(2,2,4).boxplot(wage_data,vert = False)
plt.show()

# %% [markdown]
# **Winsorization**

# %%
wage_data = visa_df['prevailing_wage']
q1 = round(np.percentile(data,25))
q2 =  round(np.percentile(data,50))
q3 = round(np.percentile(data,75))
IQR = q3-q1
UB = q3+1.5*IQR
LB = q1-1.5*IQR
visa_df['prevailing_wage2'] = wage_data.clip(lower = LB,upper = UB)
visa_df['prevailing_wage2']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    218317.5000
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage2, Length: 25480, dtype: float64

# %%
plt.figure(figsize = (8,4))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage2'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage2'],vert = False)
plt.subplot(2,2,3).hist(wage_data)
plt.subplot(2,2,4).boxplot(wage_data,vert = False)
plt.show()
